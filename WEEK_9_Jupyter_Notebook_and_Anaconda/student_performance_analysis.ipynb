# %%
import csv
import statistics
from pprint import pprint

# %%
STUDENTS_DATA_FILE = "files/students_record.csv"
REPORT_FILE = "files/school_report.txt"
#file= open(STUDENTS_DATA_FILE,"r")
#content = file.read()
#file.close()
#print(content)

# %%
def load_student_data(filename):
    """load student data from CSV file into a list of dictionary items
    
    Clean and prepare data
    """
    students = []

    with open(filename,"r") as file:
        reader = csv.DictReader(file)

        for row in reader:
            
            for key in row:
                if key in ["age", "grade_level", "math_score", "science_score", "english_score", "history_score"]:
                    row[key] = int(row[key])

                if key == "attendance rate":
                    row["attendance-rate"] = float(row["attendance_rate"])* 100

            students.append(row)
    return students

# %% [markdown]
# # Justification FOR load_student_data(filename) Method
#
# The load_student_data(filename) methos is used to load the dataset from csv file, and then the appropraite values are transformed from string to int and float, to ensure the data is eady for analysis.

# %%
def map_score_to_grade_letter(score):
    """Converts a given score to a valid grade letter"""

    if score < 0 or score > 100:
        raise Exception(" The provided score must be a value between 0 and 100")

    grade = "F"

    if score >= 90:
        grade = "A"
    elif score >= 80:
        grade = "B"
    elif score >= 70:
        grade = "C"
    elif score >= 60:
        grade = "D"
    elif score >= 50:
        grade = "E"

    return grade

# %%
def calc_total_score_for_students(students):
    """Calculates the totalscore for each student record and introduces anew "total_score" key to the student record"""

    for student in students:
        total_score = ((student["math_score"] + student["english_score"] + student["science_score"] + student["history_score"]))/4
        student["total_score"] = total_score
        student["grade"] =  map_score_to_grade_letter(total_score)

    return students

# %%
result = load_student_data(STUDENTS_DATA_FILE)
students = calc_total_score_for_students(result)
pprint(students)
# Out:
# [{'age': 16,
#   'attendance_rate': '0.97',
#   'english_score': 95,
#   'first_name': 'Emma',
#   'gender': 'F',
#   'grade': 'B',
#   'grade_level': 10,
#   'history_score': 78,
#   'last_name': 'Johnson',
#   'math_score': 92,
#   'science_score': 88,
#   'student_id': 'STU001',
#   'total_score': 88.25},
#  {'age': 15,
#   'attendance_rate': '0.89',
#   'english_score': 65,
#   'first_name': 'Liam',
#   'gender': 'M',
#   'grade': 'C',
#   'grade_level': 10,
#   'history_score': 91,
#   'last_name': 'Smith',
#   'math_score': 78,
#   'science_score': 82,
#   'student_id': 'STU002',
#   'total_score': 79.0},
#  {'age': 16,
#   'attendance_rate': '0.98',
#   'english_score': 88,
#   'first_name': 'Olivia',
#   'gender': 'F',
#   'grade': 'A',
#   'grade_level': 10,
#   'history_score': 94,
#   'last_name': 'Williams',
#   'math_score': 95,
#   'science_score': 96,
#   'student_id': 'STU003',
#   'total_score': 93.25},
#  {'age': 17,
#   'attendance_rate': '0.75',
#   'english_score': 72,
#   'first_name': 'Noah',
#   'gender': 'M',
#   'grade': 'E',
#   'grade_level': 11,
#   'history_score': 63,
#   'last_name': 'Brown',
#   'math_score': 45,
#   'science_score': 58,
#   'student_id': 'STU004',
#   'total_score': 59.5},
#  {'age': 16,
#   'attendance_rate': '0.92',
#   'english_score': 85,
#   'first_name': 'Ava',
#   'gender': 'F',
#   'grade': 'B',
#   'grade_level': 10,
#   'history_score': 80,
#   'last_name': 'Jones',
#   'math_score': 82,
#   'science_score': 79,
#   'student_id': 'STU005',
#   'total_score': 81.5},
#  {'age': 15,
#   'attendance_rate': '0.85',
#   'english_score': 72,
#   'first_name': 'William',
#   'gender': 'M',
#   'grade': 'C',
#   'grade_level': 9,
#   'history_score': 68,
#   'last_name': 'Garcia',
#   'math_score': 88,
#   'science_score': 76,
#   'student_id': 'STU006',
#   'total_score': 76.0},
#  {'age': 17,
#   'attendance_rate': '0.91',
#   'english_score': 93,
#   'first_name': 'Sophia',
#   'gender': 'F',
#   'grade': 'B',
#   'grade_level': 11,
#   'history_score': 82,
#   'last_name': 'Miller',
#   'math_score': 76,
#   'science_score': 72,
#   'student_id': 'STU007',
#   'total_score': 80.75},
#  {'age': 16,
#   'attendance_rate': '0.94',
#   'english_score': 75,
#   'first_name': 'James',
#   'gender': 'M',
#   'grade': 'B',
#   'grade_level': 10,
#   'history_score': 93,
#   'last_name': 'Davis',
#   'math_score': 83,
#   'science_score': 88,
#   'student_id': 'STU008',
#   'total_score': 84.75},
#  {'age': 15,
#   'attendance_rate': '0.93',
#   'english_score': 88,
#   'first_name': 'Isabella',
#   'gender': 'F',
#   'grade': 'B',
#   'grade_level': 9,
#   'history_score': 85,
#   'last_name': 'Rodriguez',
#   'math_score': 91,
#   'science_score': 82,
#   'student_id': 'STU009',
#   'total_score': 86.5},
#  {'age': 17,
#   'attendance_rate': '0.86',
#   'english_score': 76,
#   'first_name': 'Logan',
#   'gender': 'M',
#   'grade': 'C',
#   'grade_level': 11,
#   'history_score': 81,
#   'last_name': 'Martinez',
#   'math_score': 73,
#   'science_score': 69,
#   'student_id': 'STU010',
#   'total_score': 74.75},
#  {'age': 16,
#   'attendance_rate': '0.88',
#   'english_score': 85,
#   'first_name': 'Charlotte',
#   'gender': 'F',
#   'grade': 'C',
#   'grade_level': 10,
#   'history_score': 78,
#   'last_name': 'Hernandez',
#   'math_score': 67,
#   'science_score': 72,
#   'student_id': 'STU011',
#   'total_score': 75.5},
#  {'age': 15,
#   'attendance_rate': '0.95',
#   'english_score': 65,
#   'first_name': 'Benjamin',
#   'gender': 'M',
#   'grade': 'B',
#   'grade_level': 10,
#   'history_score': 92,
#   'last_name': 'Lopez',
#   'math_score': 94,
#   'science_score': 87,
#   'student_id': 'STU012',
#   'total_score': 84.5},
#  {'age': 17,
#   'attendance_rate': '0.97',
#   'english_score': 84,
#   'first_name': 'Mia',
#   'gender': 'F',
#   'grade': 'B',
#   'grade_level': 11,
#   'history_score': 88,
#   'last_name': 'Gonzalez',
#   'math_score': 86,
#   'science_score': 91,
#   'student_id': 'STU013',
#   'total_score': 87.25},
#  {'age': 16,
#   'attendance_rate': '0.92',
#   'english_score': 90,
#   'first_name': 'Mason',
#   'gender': 'M',
#   'grade': 'B',
#   'grade_level': 10,
#   'history_score': 76,
#   'last_name': 'Wilson',
#   'math_score': 78,
#   'science_score': 85,
#   'student_id': 'STU014',
#   'total_score': 82.25},
#  {'age': 15,
#   'attendance_rate': '0.83',
#   'english_score': 92,
#   'first_name': 'Harper',
#   'gender': 'F',
#   'grade': 'C',
#   'grade_level': 9,
#   'history_score': 71,
#   'last_name': 'Anderson',
#   'math_score': 64,
#   'science_score': 78,
#   'student_id': 'STU015',
#   'total_score': 76.25},
#  {'age': 17,
#   'attendance_rate': '0.91',
#   'english_score': 79,
#   'first_name': 'Ethan',
#   'gender': 'M',
#   'grade': 'B',
#   'grade_level': 11,
#   'history_score': 87,
#   'last_name': 'Thomas',
#   'math_score': 91,
#   'science_score': 85,
#   'student_id': 'STU016',
#   'total_score': 85.5},
#  {'age': 16,
#   'attendance_rate': '0.94',
#   'english_score': 88,
#   'first_name': 'Amelia',
#   'gender': 'F',
#   'grade': 'B',
#   'grade_level': 10,
#   'history_score': 92,
#   'last_name': 'Taylor',
#   'math_score': 83,
#   'science_score': 78,
#   'student_id': 'STU017',
#   'total_score': 85.25},
#  {'age': 16,
#   'attendance_rate': '0.79',
#   'english_score': 68,
#   'first_name': 'Alexander',
#   'gender': 'M',
#   'grade': 'D',
#   'grade_level': 10,
#   'history_score': 65,
#   'last_name': 'Moore',
#   'math_score': 72,
#   'science_score': 74,
#   'student_id': 'STU018',
#   'total_score': 69.75},
#  {'age': 15,
#   'attendance_rate': '0.96',
#   'english_score': 95,
#   'first_name': 'Evelyn',
#   'gender': 'F',
#   'grade': 'A',
#   'grade_level': 9,
#   'history_score': 88,
#   'last_name': 'Jackson',
#   'math_score': 89,
#   'science_score': 93,
#   'student_id': 'STU019',
#   'total_score': 91.25},
#  {'age': 17,
#   'attendance_rate': '0.88',
#   'english_score': 77,
#   'first_name': 'Michael',
#   'gender': 'M',
#   'grade': 'B',
#   'grade_level': 11,
#   'history_score': 79,
#   'last_name': 'Martin',
#   'math_score': 85,
#   'science_score': 81,
#   'student_id': 'STU020',
#   'total_score': 80.5}]

# %%
def calculate_statistics(students):
    """ Calculates statistical measure for students total score """

    scores = []
    for student in students:
        scores.append(student["total_score"])

    # An alternative to achieve the above is by list comprehension
    # scores = [student[total_score] for student in students]

    return {
        "mean": statistics.mean(scores),
        "median": statistics.median(scores),
        # Ternary operator- a shorthod of writing(if/else statement)
        "std_dev": statistics.stdev(scores) if len(scores) > 1 else 0,
        "min": min(scores),
        "max": max(scores),
    }

# %%
def get_student_total_score(student):
    return student["total_score"]

def get_best_performing_student(students):
    """ Returns the student with the highest total score"""
    student= max(students, key=get_student_total_score)
    
    return f"{student["first_name"]} {student["last_name"]}"

# %%
def generate_school_report(students):
    """Complie studemts performance report and output to a text file"""
   
    best_student = get_best_performing_student(students)

    stats = calculate_statistics(students)

    with open(REPORT_FILE,"w") as file:
        file.write("SCHOOL REPORT \n")
        file.write("="*60 + "\n\n")

        # stats
        file.write("SCHOOL STATISTICS\n")
        file.write("="*60 + "\n")

        file.write(f"Total Number of Students: {len(students)}\n")
        file.write(f"Score Mean: {stats["mean"]:,.1f}\n")
        file.write(f"Score Median:{stats["median"]:,.1f}\n")
        file.write(f"Score Standard Deviation: {stats["std_dev"]:,.1f}\n")
        file.write(f"Score Range: from {stats["min"]} to  {stats["max"]:,.1f}\n")
                                                           
        file.write("\n\nSTUDENT RECOGNITION\n")
        file.write("="*60 + "\n\n")                                                  

        file.write(f"Best Performing Student: {best_student}\n")

        file.write("\n\nStudents Details Highlight\n")                                                   
        file.write("="*60 + "\n")                                                  
        file.write(f"{'Name': <24} {'Score': <8} {'Attendance': <12} {'Grade': <5}\n")  

        for student in sorted(students, key = get_student_total_score, reverse = True):
            student_name = f"{student["first_name"]} {student["last_name"]}"
            file.write(f"{student_name:<24} {student["total_score"]:<8} {student["attendance_rate"]:<24} {student["grade"]:<5}\n")

# %%
dataset = load_student_data(STUDENTS_DATA_FILE)
students = calc_total_score_for_students(dataset)

generate_school_report(students)
