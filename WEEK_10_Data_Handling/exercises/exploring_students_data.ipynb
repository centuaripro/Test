# %%
import pandas as pd

# %%
# load data into 
students_df = pd.read_csv("../files/students_record.csv")

# %%
# Exploring the data structure
print("\n=============DATA EXPLORATION===================")
(rows, columns)= students_df.shape
print(f"\n{rows} rows, {columns} columns")

print("\n=============DATA TYPES===================")
print(students_df.dtypes)

print("\n=============MISSING VALUES===================")
print("\nMissing values in each column")
print(students_df.isnull().sum())

print("\n=============DATASET PREVIEW===================")
print(students_df.head())
# Out:
# =============DATA EXPLORATION===================
#
# 20 rows, 11 columns
#
# =============DATA TYPES===================
# student_id             str
# first_name             str
# last_name              str
# gender                 str
# age                  int64
# grade_level          int64
# math_score           int64
# science_score        int64
# english_score        int64
# history_score        int64
# attendance_rate    float64
# dtype: object
#
# =============MISSING VALUES===================
#
# Missing values in each column
# student_id         0
# first_name         0
# last_name          0
# gender             0
# age                0
# grade_level        0
# math_score         0
# science_score      0
# english_score      0
# history_score      0
# attendance_rate    0
# dtype: int64
#
# =============DATASET PREVIEW===================
#   student_id first_name last_name gender  age  grade_level  math_score  \
# 0     STU001       Emma   Johnson      F   16           10          92
# 1     STU002       Liam     Smith      M   15           10          78
# 2     STU003     Olivia  Williams      F   16           10          95
# 3     STU004       Noah     Brown      M   17           11          45
# 4     STU005        Ava     Jones      F   16           10          82
#
#    science_score  english_score  history_score  attendance_rate
# 0             88             95             78             0.97
# 1             82             65             91             0.89
# 2             96             88             94             0.98
# 3             58             72             63             0.75
# 4             79             85             80             0.92

# %%
print(students_df.columns)
# Out:
# Index(['student_id', 'first_name', 'last_name', 'gender', 'age', 'grade_level',
#        'math_score', 'science_score', 'english_score', 'history_score',
#        'attendance_rate'],
#       dtype='str')

# %%
# age                  int64
# grade_level          int64
# math_score           int64
# science_score        int64
# english_score        int64
# history_score        int64
# attendance_rate    float64

columns= students_df.columns
subject_cols = []

for col in columns:
    if "_score" in col:
        subject_cols.append(col)

stats_summary = students_df[subject_cols].describe()

print(stats_summary)
# Out:
#        math_score  science_score  english_score  history_score
# count    20.00000      20.000000      20.000000      20.000000
# mean     80.60000      80.700000      81.600000      81.550000
# std      12.17158       9.079184       9.848323       9.450564
# min      45.00000      58.000000      65.000000      63.000000
# 25%      75.25000      75.500000      74.250000      77.500000
# 50%      83.00000      81.500000      84.500000      81.500000
# 75%      89.50000      87.250000      88.500000      88.750000
# max      95.00000      96.000000      95.000000      94.000000

# %%
students_df["average_score"] = students_df[subject_cols].mean(axis=1).round(2)

top_students = students_df.sort_values("average_score", ascending= False)
print(top_students.head())
# Out:
#    student_id first_name  last_name gender  age  grade_level  math_score  \
# 2      STU003     Olivia   Williams      F   16           10          95
# 18     STU019     Evelyn    Jackson      F   15            9          89
# 0      STU001       Emma    Johnson      F   16           10          92
# 12     STU013        Mia   Gonzalez      F   17           11          86
# 8      STU009   Isabella  Rodriguez      F   15            9          91
#
#     science_score  english_score  history_score  attendance_rate  \
# 2              96             88             94             0.98
# 18             93             95             88             0.96
# 0              88             95             78             0.97
# 12             91             84             88             0.97
# 8              82             88             85             0.93
#
#     average_score
# 2           93.25
# 18          91.25
# 0           88.25
# 12          87.25
# 8           86.50

# %%
def determine_pass_or_fail(average_score):
    return average_score >=75


students_df["pass_fail"] = students_df["average_score"].apply(determine_pass_or_fail)
print(students_df)
# Out:
#    student_id first_name  last_name gender  age  grade_level  math_score  \
# 0      STU001       Emma    Johnson      F   16           10          92
# 1      STU002       Liam      Smith      M   15           10          78
# 2      STU003     Olivia   Williams      F   16           10          95
# 3      STU004       Noah      Brown      M   17           11          45
# 4      STU005        Ava      Jones      F   16           10          82
# 5      STU006    William     Garcia      M   15            9          88
# 6      STU007     Sophia     Miller      F   17           11          76
# 7      STU008      James      Davis      M   16           10          83
# 8      STU009   Isabella  Rodriguez      F   15            9          91
# 9      STU010      Logan   Martinez      M   17           11          73
# 10     STU011  Charlotte  Hernandez      F   16           10          67
# 11     STU012   Benjamin      Lopez      M   15           10          94
# 12     STU013        Mia   Gonzalez      F   17           11          86
# 13     STU014      Mason     Wilson      M   16           10          78
# 14     STU015     Harper   Anderson      F   15            9          64
# 15     STU016      Ethan     Thomas      M   17           11          91
# 16     STU017     Amelia     Taylor      F   16           10          83
# 17     STU018  Alexander      Moore      M   16           10          72
# 18     STU019     Evelyn    Jackson      F   15            9          89
# 19     STU020    Michael     Martin      M   17           11          85
#
#     science_score  english_score  history_score  attendance_rate  \
# 0              88             95             78             0.97
# 1              82             65             91             0.89
# 2              96             88             94             0.98
# 3              58             72             63             0.75
# 4              79             85             80             0.92
# 5              76             72             68             0.85
# 6              72             93             82             0.91
# 7              88             75             93             0.94
# 8              82             88             85             0.93
# 9              69             76             81             0.86
# 10             72             85             78             0.88
# 11             87             65             92             0.95
# 12             91             84             88             0.97
# 13             85             90             76             0.92
# 14             78             92             71             0.83
# 15             85             79             87             0.91
# 16             78             88             92             0.94
# 17             74             68             65             0.79
# 18             93             95             88             0.96
# 19             81             77             79             0.88
#
#     average_score  pass_fail
# 0           88.25       True
# 1           79.00       True
# 2           93.25       True
# 3           59.50      False
# 4           81.50       True
# 5           76.00       True
# 6           80.75       True
# 7           84.75       True
# 8           86.50       True
# 9           74.75      False
# 10          75.50       True
# 11          84.50       True
# 12          87.25       True
# 13          82.25       True
# 14          76.25       True
# 15          85.50       True
# 16          85.25       True
# 17          69.75      False
# 18          91.25       True
# 19          80.50       True

# %%
pass_fail_counts= students_df["pass_fail"].value_counts()

print(f"\nPass Percentage: {pass_fail_counts[True]/ len(students_df)*100}%")
# Out:
# Pass Percentage: 85.0%
