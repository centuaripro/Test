# %%
import pandas as pd

# %%
students_df = pd.read_csv("files/students_record.csv")

print("DataFrame Shape (rows,column):", students_df.shape)
print("\nColumn names (in the form of a list):", students_df.columns.tolist())

print("\nData types:")
print(students_df.dtypes)

# %%
# Accessing columns
print("\nLast names:")
print(students_df['last_name'])

# %%
#filtering- in this case we wre filtering for students with maths score greater or equal to 90
high_scores = students_df[students_df["math_score"]>=90]
print(high_scores)

# %%
# Conditional selection
new_df = (students_df[["student_id", "first_name", "last_name", "age", "gender"]])
print(new_df)
# Out:
#    student_id first_name  last_name  age gender
# 0      STU001       Emma    Johnson   16      F
# 1      STU002       Liam      Smith   15      M
# 2      STU003     Olivia   Williams   16      F
# 3      STU004       Noah      Brown   17      M
# 4      STU005        Ava      Jones   16      F
# 5      STU006    William     Garcia   15      M
# 6      STU007     Sophia     Miller   17      F
# 7      STU008      James      Davis   16      M
# 8      STU009   Isabella  Rodriguez   15      F
# 9      STU010      Logan   Martinez   17      M
# 10     STU011  Charlotte  Hernandez   16      F
# 11     STU012   Benjamin      Lopez   15      M
# 12     STU013        Mia   Gonzalez   17      F
# 13     STU014      Mason     Wilson   16      M
# 14     STU015     Harper   Anderson   15      F
# 15     STU016      Ethan     Thomas   17      M
# 16     STU017     Amelia     Taylor   16      F
# 17     STU018  Alexander      Moore   16      M
# 18     STU019     Evelyn    Jackson   15      F
# ...
